# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import urllib.parse

# %%
business_type = 'landscape'
business_city = urllib.parse.quote('Baton Rouge')
business_state = urllib.parse.quote('LA')
yellow_pages_url = f'https://www.yellowpages.com/search?search_terms={business_type}&geo_location_terms={business_city}%2C+{business_state}'

# %%
yp_page = requests.get(yellow_pages_url)
yp_soup = BeautifulSoup(yp_page.text,'html')

# %%
companies = yp_soup.find_all(class_='result')
#print(companies)

# %%
yp_business_names = []
yp_phones = []
yp_address_list = []

# %%
for company in yp_soup.find_all('div',class_='result'):
    name = company.find('a',class_='business-name')
    b_name = name.text.strip() if name else 'None'
    #print(b_name)
    phone = company.find('div',class_='phones phone primary')
    phone_num = phone.text.strip() if phone else 'None'
    #print(phone_num)
    address = company.find('div',class_='street-address')
    street_address = address.text.strip() if address else 'None'
    #print(street_address)
    yp_business_names.append(b_name)
    yp_phones.append(phone_num)
    yp_address_list.append(street_address)

# %%
df = pd.DataFrame({
    'Company Name': business_names,
    'Phone Number': phones,
    'Address': address_list,
})
df = df.sort_values(by='Company Name')
display(df.style.hide_index())
# Out:
# /var/folders/zw/m6lz6_8d3jl6q1hv5qg_dm040000gn/T/ipykernel_34155/1295298002.py:7: FutureWarning: this method is deprecated in favour of `Styler.hide(axis="index")`
#   display(df.style.hide_index())
# <style type="text/css">
# </style>
# <table id="T_82532">
#   <thead>
#     <tr>
#       <th id="T_82532_level0_col0" class="col_heading level0 col0" >Company Name</th>
#       <th id="T_82532_level0_col1" class="col_heading level0 col1" >Phone Number</th>
#       <th id="T_82532_level0_col2" class="col_heading level0 col2" >Address</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_82532_row0_col0" class="data row0 col0" >A Green Affair</td>
#       <td id="T_82532_row0_col1" class="data row0 col1" >(225) 773-3152</td>
#       <td id="T_82532_row0_col2" class="data row0 col2" >None</td>
#     </tr>
#     <tr>
#       <td id="T_82532_row1_col0" class="data row1 col0" >ADAMS HANDYMAN SERVICES</td>
#       <td id="T_82532_row1_col1" class="data row1 col1" >(888) 316-5235</td>
#       <td id="T_82532_row1_col2" class="data row1 col2" >PO Box,</td>
#     </tr>
#     <tr>
#       <td id="T_82532_row2_col0" class="data row2 col0" >Ascension Tree And Stump LLC</td>
#       <td id="T_82532_row2_col1" class="data row2 col1" >(888) 679-1615</td>
#       <td id="T_82532_row2_col2" class="data row2 col2" >None</td>
#     </tr>
#     <tr>
#       <td id="T_82532_row3_col0" class="data row3 col0" >Baton Rouge Horticultural Service</td>
#       <td id="T_82532_row3_col1" class="data row3 col1" >(225) 924-5884</td>
#       <td id="T_82532_row3_col2" class="data row3 col2" >2222 Bardwell Dr</td>
#     </tr>
#     <tr>
#       <td id="T_82532_row4_col0" class="data row4 col0" >Blue Skies Landscape LLC</td>
#       <td id="T_82532_row4_col1" class="data row4 col1" >(225) 772-4183</td>
#       <td id="T_82532_row4_col2" class="data row4 col2" >None</td>
#     </tr>
#     <tr>
#       <td id="T_82532_row5_col0" class="data row5 col0" >Bonfiglio Lawn & Landscape</td>
#       <td id="T_82532_row5_col1" class="data row5 col1" >(225) 447-8880</td>
#       <td id="T_82532_row5_col2" class="data row5 col2" >7195 Scobell Dr</td>
#     </tr>
#     <tr>
#       <td id="T_82532_row6_col0" class="data row6 col0" >C & M Outdoor Power Equipment</td>
#       <td id="T_82532_row6_col1" class="data row6 col1" >(225) 271-5352</td>
#       <td id="T_82532_row6_col2" class="data row6 col2" >8472 Florida Blvd</td>
#     </tr>
#     <tr>
#       <td id="T_82532_row7_col0" class="data row7 col0" >Chop Chop Landscaping in Baton Rouge</td>
#       <td id="T_82532_row7_col1" class="data row7 col1" >(225) 240-8586</td>
#       <td id="T_82532_row7_col2" class="data row7 col2" >301 Main St</td>
#     </tr>
#     <tr>
#       <td id="T_82532_row8_col0" class="data row8 col0" >Evergreen landscape</td>
#       <td id="T_82532_row8_col1" class="data row8 col1" >(225) 803-5979</td>
#       <td id="T_82532_row8_col2" class="data row8 col2" >11675 E Black Oak Dr</td>
#     </tr>
#     <tr>
#       <td id="T_82532_row9_col0" class="data row9 col0" >HD Lawn and Landscape, LLC</td>
#       <td id="T_82532_row9_col1" class="data row9 col1" >(225) 402-7978</td>
#       <td id="T_82532_row9_col2" class="data row9 col2" >13931 Rampart Ct</td>
#     </tr>
#     <tr>
#       <td id="T_82532_row10_col0" class="data row10 col0" >Harb's Oasis</td>
#       <td id="T_82532_row10_col1" class="data row10 col1" >(225) 756-2720</td>
#       <td id="T_82532_row10_col2" class="data row10 col2" >13827 Coursey Blvd</td>
#     </tr>
#     <tr>
#       <td id="T_82532_row11_col0" class="data row11 col0" >Hernandez Lawnscape</td>
#       <td id="T_82532_row11_col1" class="data row11 col1" >(225) 347-9540</td>
#       <td id="T_82532_row11_col2" class="data row11 col2" >16148 Confederate Ave</td>
#     </tr>
#     <tr>
#       <td id="T_82532_row12_col0" class="data row12 col0" >Landscape Baton Rouge LLC</td>
#       <td id="T_82532_row12_col1" class="data row12 col1" >(225) 663-4910</td>
#       <td id="T_82532_row12_col2" class="data row12 col2" >8748 Quarters Lake Rd</td>
#     </tr>
#     <tr>
#       <td id="T_82532_row13_col0" class="data row13 col0" >Landscaping Baton Rouge</td>
#       <td id="T_82532_row13_col1" class="data row13 col1" >(225) 242-9937</td>
#       <td id="T_82532_row13_col2" class="data row13 col2" >8335 Summa Ave Apt 1</td>
#     </tr>
#     <tr>
#       <td id="T_82532_row14_col0" class="data row14 col0" >Lavergne Lawn Service</td>
#       <td id="T_82532_row14_col1" class="data row14 col1" >(225) 397-7256</td>
#       <td id="T_82532_row14_col2" class="data row14 col2" >9933 avenue b apt b</td>
#     </tr>
#     <tr>
#       <td id="T_82532_row15_col0" class="data row15 col0" >Leeson Landscape Care</td>
#       <td id="T_82532_row15_col1" class="data row15 col1" >(225) 465-1600</td>
#       <td id="T_82532_row15_col2" class="data row15 col2" >4228 Rhoda Dr</td>
#     </tr>
#     <tr>
#       <td id="T_82532_row16_col0" class="data row16 col0" >Louisiana Lawniappe LLC</td>
#       <td id="T_82532_row16_col1" class="data row16 col1" >(225) 234-0992</td>
#       <td id="T_82532_row16_col2" class="data row16 col2" >None</td>
#     </tr>
#     <tr>
#       <td id="T_82532_row17_col0" class="data row17 col0" >Newton Landscape Group</td>
#       <td id="T_82532_row17_col1" class="data row17 col1" >(225) 756-4321</td>
#       <td id="T_82532_row17_col2" class="data row17 col2" >8930 Buzbee Dr</td>
#     </tr>
#     <tr>
#       <td id="T_82532_row18_col0" class="data row18 col0" >Pennington Lawn & Landscape</td>
#       <td id="T_82532_row18_col1" class="data row18 col1" >(225) 761-0008</td>
#       <td id="T_82532_row18_col2" class="data row18 col2" >233 Rodney Dr</td>
#     </tr>
#     <tr>
#       <td id="T_82532_row19_col0" class="data row19 col0" >Persac Lawn & Landscape</td>
#       <td id="T_82532_row19_col1" class="data row19 col1" >(985) 630-3012</td>
#       <td id="T_82532_row19_col2" class="data row19 col2" >1526 Saint Alban's Drive</td>
#     </tr>
#     <tr>
#       <td id="T_82532_row20_col0" class="data row20 col0" >Persac Lawn & Landscape, LLC</td>
#       <td id="T_82532_row20_col1" class="data row20 col1" >(225) 610-7336</td>
#       <td id="T_82532_row20_col2" class="data row20 col2" >Po Box 84024</td>
#     </tr>
#     <tr>
#       <td id="T_82532_row21_col0" class="data row21 col0" >Philip Moser Associates</td>
#       <td id="T_82532_row21_col1" class="data row21 col1" >(225) 234-0421</td>
#       <td id="T_82532_row21_col2" class="data row21 col2" >15256 S Harrells Ferry Rd</td>
#     </tr>
#     <tr>
#       <td id="T_82532_row22_col0" class="data row22 col0" >ProGreen Lawn & Landscape, LLC</td>
#       <td id="T_82532_row22_col1" class="data row22 col1" >(225) 223-9077</td>
#       <td id="T_82532_row22_col2" class="data row22 col2" >4250 Bea Dr</td>
#     </tr>
#     <tr>
#       <td id="T_82532_row23_col0" class="data row23 col0" >RS Outdoors LLC</td>
#       <td id="T_82532_row23_col1" class="data row23 col1" >(225) 275-4500</td>
#       <td id="T_82532_row23_col2" class="data row23 col2" >2202 Hunters Trail Dr</td>
#     </tr>
#     <tr>
#       <td id="T_82532_row24_col0" class="data row24 col0" >River City Landscaping</td>
#       <td id="T_82532_row24_col1" class="data row24 col1" >(225) 364-2024</td>
#       <td id="T_82532_row24_col2" class="data row24 col2" >7987 Pecue Ln Ste 9</td>
#     </tr>
#     <tr>
#       <td id="T_82532_row25_col0" class="data row25 col0" >Smith & Baker Landscapes</td>
#       <td id="T_82532_row25_col1" class="data row25 col1" >(225) 202-8875</td>
#       <td id="T_82532_row25_col2" class="data row25 col2" >7435 Town South Ave</td>
#     </tr>
#     <tr>
#       <td id="T_82532_row26_col0" class="data row26 col0" >Steve  Robins Tree Service</td>
#       <td id="T_82532_row26_col1" class="data row26 col1" >(225) 925-0610</td>
#       <td id="T_82532_row26_col2" class="data row26 col2" >9663 Great Smokey Ave</td>
#     </tr>
#     <tr>
#       <td id="T_82532_row27_col0" class="data row27 col0" >T-N-T Pool Company</td>
#       <td id="T_82532_row27_col1" class="data row27 col1" >(225) 665-0226</td>
#       <td id="T_82532_row27_col2" class="data row27 col2" >9104 Arnold Rd</td>
#     </tr>
#     <tr>
#       <td id="T_82532_row28_col0" class="data row28 col0" >Treppendahl Landscape</td>
#       <td id="T_82532_row28_col1" class="data row28 col1" >(225) 681-9621</td>
#       <td id="T_82532_row28_col2" class="data row28 col2" >594
